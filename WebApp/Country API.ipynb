# %%
import requests

class CountriesAPI:
    
    def __init__(self):
        self.base_url = "https://restcountries.com/v3.1"

    def searchByName(self, data):
        url = self.base_url + "/name/" + data
        return url
    
    def searchByCurrency(self,data):
        url = self.base_url + "/currency/" + data
        return url

    def searchByLanguage(self,data):
        url = self.base_url + "/lang/" + data
        return url

    def searchByCapitalCity(self,data):
        url = self.base_url + "/capital/" + data
        return url

    def createCountry(self, url):
        
        try:
            # Call the API by opening the url and reading the data.
            response = requests.get(url)

            if response.status_code == 200:
                data = {}
                response = response.json()[0]

                data['name'] = response['name']['common']
                data['currencies'] = dict(response['currencies'])
                data['capital'] = response['capital'][0]
                data['region'] = response['region']
                data['subregion'] = response['subregion']
                data['languages'] = dict(response['languages'])
                data['population'] = response['population']
                data['timezones'] = response['timezones']

                country = Country(data)
                return country
            else:
                return {"error": "Failed to fetch a joke from the Country API."}

        except Exception as e:
            return {"error": f"An error occurred: {str(e)}"}


class Country:
    
    def __init__(self, data):
        self.name = data["name"]
        self.currencies = data["currencies"]
        self.capital = data["capital"]
        self.region = data["region"]
        self.subregion = data["subregion"]
        self.languages = data["languages"]
        self.population = data["population"]
        self.timezones = data["timezones"]

    def printCountryData(self):
        
        data = ""
        data += f"\nName: {self.name}" 
        data += f"\nCurrencies: {', '.join(self.currencies.keys())}" 
        data += f"\nCapital: {self.capital}" 
        data += f"\nRegion: {self.region}" 
        data += f"\nSubregion: {self.subregion}" 
        data += f"\nLanguages: {', '.join(self.languages.values())}" 
        data += f"\nPopulation: {self.population}" 
        data += f"\nTimezones: {', '.join(self.timezones)}" 

        return data

def main():
    country_api = CountriesAPI()
    url = country_api.searchByName(data="Malaysia")
    url = country_api.searchByCurrency(data="Malaysia")
    url = country_api.searchByLanguage(data="Malaysia")
    url = country_api.searchByCapitalCity(data="Malaysia")
    
    country = country_api.createCountry(url)
    
    print(country.printCountryData())
     
if __name__ == "__main__":
    main()
# Out:
#   Cell In[10], line 59
#     def main():
#                ^
# IndentationError: expected an indented block after function definition on line 56

# %%
import requests

class CountriesAPI:
    
    def __init__(self):
        self.base_url = "https://restcountries.com/v3.1"

    def searchByName(self, data):
        url = self.base_url + "/name/" + data
        return url
    
    def searchByCurrency(self,data):
        url = self.base_url + "/currency/" + data
        return url

    def searchByLanguage(self,data):
        url = self.base_url + "/lang/" + data
        return url

    def searchByCapitalCity(self,data):
        url = self.base_url + "/capital/" + data
        return url

    def createCountry(self, url):
        
        try:
            # Call the API by opening the url and reading the data.
            response = requests.get(url)

            if response.status_code == 200:
                data = {}
                response = response.json()[0]

                data['name'] = response['name']['common']
                data['currencies'] = dict(response['currencies'])
                data['capital'] = response['capital'][0]
                data['region'] = response['region']
                data['subregion'] = response['subregion']
                data['languages'] = dict(response['languages'])
                data['population'] = response['population']
                data['timezones'] = response['timezones']

                country = Country(data)
                return country
            else:
                return {"error": "Failed to fetch a joke from the Country API."}

        except Exception as e:
            return {"error": f"An error occurred: {str(e)}"}


class Country:
    
    def __init__(self, data):
        self.name = data["name"]
        self.currencies = data["currencies"]
        self.capital = data["capital"]
        self.region = data["region"]
        self.subregion = data["subregion"]
        self.languages = data["languages"]
        self.population = data["population"]
        self.timezones = data["timezones"]

    def printCountryData(self):
        
        data = ""
        data += f"\nName: {self.name}" 
        data += f"\nCurrencies: {', '.join(self.currencies.keys())}" 
        data += f"\nCapital: {self.capital}" 
        data += f"\nRegion: {self.region}" 
        data += f"\nSubregion: {self.subregion}" 
        data += f"\nLanguages: {', '.join(self.languages.values())}" 
        data += f"\nPopulation: {self.population}" 
        data += f"\nTimezones: {', '.join(self.timezones)}" 

        return data

def main():
    country_api = CountriesAPI()
    url = country_api.searchByCapitalCity(data="Kuala Lumpur")
    country = country_api.createCountry(url)
    
    if isinstance(country, Country):
        print(country.printCountryData())
    else:
        print("Error:", country["error"])

if __name__ == "__main__":
    main()
     
if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 86
#      83     print(country.printCountryData())
#      85 if __name__ == "__main__":
# ---> 86     main()
#
# Cell In[1], line 83, in main()
#      80 url = country_api.searchByCapitalCity(data="Kuala Lumpur")
#      81 country = country_api.createCountry(url)
# ---> 83 print(country.printCountryData())
#
# AttributeError: 'dict' object has no attribute 'printCountryData'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 86
#      83     print(country.printCountryData())
#      85 if __name__ == "__main__":
# ---> 86     main()
#
# Cell In[3], line 83, in main()
#      80 url = country_api.searchByCapitalCity(data="Kuala Lumpur")
#      81 country = country_api.createCountry(url)
# ---> 83 print(country.printCountryData())
#
# AttributeError: 'dict' object has no attribute 'printCountryData'
